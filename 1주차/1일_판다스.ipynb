# %% [markdown]
# <a href="https://colab.research.google.com/github/YangHyunu/SKT-FLY-AI-5/blob/main/1%EC%A3%BC%EC%B0%A8/1%EC%9D%BC_%ED%8C%90%EB%8B%A4%EC%8A%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy  as np
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.3'

# %% [markdown]
# ## Series

# %%
sr = pd.Series([1,2,4,5,6])
sr
# type(sr)
# Out:
# 0    1
# 1    2
# 2    4
# 3    5
# 4    6
# dtype: int64

# %%
sr=pd.Series([1,2,4,5,6],index=['a','b','c','d','e'],name='point')
sr
# Out:
# a    1
# b    2
# c    4
# d    5
# e    6
# Name: point, dtype: int64

# %%
sr.name
# Out:
# 'point'

# %%
sr.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
sr.shape
# Out:
# (5,)

# %%
sr.values
# Out:
# array([1, 2, 4, 5, 6])

# %%
sr +5
# Out:
# a     6
# b     7
# c     9
# d    10
# e    11
# Name: point, dtype: int64

# %%
sr1 = pd.Series([1,None,4],index=['a','b','c'])
sr1
# Out:
# a    1.0
# b    NaN
# c    4.0
# dtype: float64

# %%
sr1.isna()
# Out:
# a    False
# b     True
# c    False
# dtype: bool

# %%
sr1[sr1.isna()]
# Out:
# b   NaN
# dtype: float64

# %%
sr>2
# Out:
# a    False
# b    False
# c     True
# d     True
# e     True
# Name: point, dtype: bool

# %% [markdown]
# ## DataFrame

# %%
info = {
    'Name':['Jackson', 'Emma', 'Noah', 'James'],
    'Weight':[68, 74, 77, 78],
    'Option':[True, True, False, False],
    'Rate':[0.21, 1.1, 0.89, 0.91],
    'Type':['A','A','C','C']
}
df = pd.DataFrame(info)
df
# Out:
#       Name  Weight  Option  Rate Type
# 0  Jackson      68    True  0.21    A
# 1     Emma      74    True  1.10    A
# 2     Noah      77   False  0.89    C
# 3    James      78   False  0.91    C

# %%
#df.shape
df.index
# df.info()
df.columns
df.values
# Out:
# array([['Jackson', 68, True, 0.21, 'A'],
#        ['Emma', 74, True, 1.1, 'A'],
#        ['Noah', 77, False, 0.89, 'C'],
#        ['James', 78, False, 0.91, 'C']], dtype=object)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/devdio/flyai_datasets/main/vgsalesGlobale.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA Sales  EU Sales  JP Sales  \
# ...

# %%
# df.shape
df.info()
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA Sales      16598 non-null  float64
#  7   EU Sales      16598 non-null  float64
#  8   JP Sales      16598 non-null  float64
#  9   Other Sales   16598 non-null  float64
#  10  Global Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# ...

# %%
df.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA Sales          0
# EU Sales          0
# JP Sales          0
# Other Sales       0
# Global Sales      0
# dtype: int64

# %%
df.describe()
# Out:
#                Rank          Year      NA Sales      EU Sales      JP Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other Sales  Global Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df.isna().any(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16593    False
# 16594    False
# 16595    False
# 16596    False
# 16597    False
# Length: 16598, dtype: bool

# %%
df[df.isna().any(axis=1)]
# Out:
#         Rank                             Name Platform    Year         Genre  \
# 179      180                  Madden NFL 2004      PS2     NaN        Sports
# 377      378                 FIFA Soccer 2004      PS2     NaN        Sports
# 431      432       LEGO Batman: The Videogame      Wii     NaN        Action
# 470      471       wwe Smackdown vs. Raw 2006      PS2     NaN      Fighting
# 607      608                   Space Invaders     2600     NaN       Shooter
# ...      ...                              ...      ...     ...           ...
# 16427  16430                     Virtua Quest       GC     NaN  Role-Playing
# 16493  16496                       The Smurfs      3DS     NaN        Action
# 16494  16497  Legends of Oz: Dorothy's Return      3DS  2014.0        Puzzle
# 16543  16546           Driving Simulator 2011       PC  2011.0        Racing
# 16553  16556                   Bound By Flame     X360  2014.0  Role-Playing
#
# ...

# %%
df['Global Sales']
df[['Global Sales',]]
# type(df['Global Sales'])
# Out:
#        Global Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16598 rows x 1 columns]

# %%
df[['Global Sales','JP Sales']]
# Out:
#        Global Sales  JP Sales
# 0             82.74      3.77
# 1             40.24      6.81
# 2             35.82      3.79
# 3             33.00      3.28
# 4             31.37     10.22
# ...             ...       ...
# 16593          0.01      0.00
# 16594          0.01      0.00
# 16595          0.01      0.00
# 16596          0.01      0.00
# 16597          0.01      0.00
#
# [16598 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA Sales',
#        'EU Sales', 'JP Sales', 'Other Sales', 'Global Sales'],
#       dtype='object')

# %%
[col.lower().replace(' ','_') for col in df.columns]
# Out:
# ['rank',
#  'name',
#  'platform',
#  'year',
#  'genre',
#  'publisher',
#  'na_sales',
#  'eu_sales',
#  'jp_sales',
#  'other_sales',
#  'global_sales']

# %%
df.columns = [col.lower().replace(' ','_') for col in df.columns]
df
# Out:
#         rank                                              name platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          year         genre   publisher  na_sales  eu_sales  jp_sales  \
# ...

# %%
df[df.global_sales>40]
# Out:
#    rank               name platform    year     genre publisher  na_sales  \
# 0     1         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
#
#    eu_sales  jp_sales  other_sales  global_sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24

# %%
df[(df.global_sales>40) & (df.jp_sales<10)]
df[(df.global_sales>40) | (df.jp_sales<10)]
# Out:
#         rank                                              name platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 5          6                                            Tetris       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          year     genre   publisher  na_sales  eu_sales  jp_sales  \
# ...

# %%
df.loc[(df.global_sales>40),'jp_sales']
# Out:
# 0    3.77
# 1    6.81
# Name: jp_sales, dtype: float64

# %%
df.loc[(df.global_sales>40),['jp_sales','name']]
# Out:
#    jp_sales               name
# 0      3.77         Wii Sports
# 1      6.81  Super Mario Bros.

# %%
df.iloc[0,[0,1]]
# Out:
# rank             1
# name    Wii Sports
# Name: 0, dtype: object

# %%
df.iloc[0:4,[0,1]]
# Out:
#    rank               name
# 0     1         Wii Sports
# 1     2  Super Mario Bros.
# 2     3     Mario Kart Wii
# 3     4  Wii Sports Resort

# %%
df_num= df.select_dtypes(include='number')
df_num
df_num.info()
df_num['global_sales_twice'] = df_num['global_sales']*2
df_num
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rank          16598 non-null  int64
#  1   year          16327 non-null  float64
#  2   na_sales      16598 non-null  float64
#  3   eu_sales      16598 non-null  float64
#  4   jp_sales      16598 non-null  float64
#  5   other_sales   16598 non-null  float64
#  6   global_sales  16598 non-null  float64
# dtypes: float64(6), int64(1)
# memory usage: 907.8 KB
#         rank    year  na_sales  eu_sales  jp_sales  other_sales  global_sales  \
# 0          1  2006.0     41.49     29.02      3.77         8.46         82.74
# 1          2  1985.0     29.08      3.58      6.81         0.77         40.24
# 2          3  2008.0     15.85     12.88      3.79         3.31         35.82
# 3          4  2009.0     15.75     11.01      3.28         2.96         33.00
# ...

# %%
df_num.drop('global_sales_twice',axis=1,inplace=True)

# %%
df_num
# Out:
#         rank    year  na_sales  eu_sales  jp_sales  other_sales  global_sales
# 0          1  2006.0     41.49     29.02      3.77         8.46         82.74
# 1          2  1985.0     29.08      3.58      6.81         0.77         40.24
# 2          3  2008.0     15.85     12.88      3.79         3.31         35.82
# 3          4  2009.0     15.75     11.01      3.28         2.96         33.00
# 4          5  1996.0     11.27      8.89     10.22         1.00         31.37
# ...      ...     ...       ...       ...       ...          ...           ...
# 16593  16596  2002.0      0.01      0.00      0.00         0.00          0.01
# 16594  16597  2003.0      0.01      0.00      0.00         0.00          0.01
# 16595  16598  2008.0      0.00      0.00      0.00         0.00          0.01
# 16596  16599  2010.0      0.00      0.01      0.00         0.00          0.01
# 16597  16600  2003.0      0.01      0.00      0.00         0.00          0.01
#
# [16598 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# rank              0
# name              0
# platform          0
# year            271
# genre             0
# publisher        58
# na_sales          0
# eu_sales          0
# jp_sales          0
# other_sales       0
# global_sales      0
# dtype: int64

# %%
df['publisher'].value_counts()
# Out:
# publisher
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
#                                 ...
# Warp                               1
# New                                1
# Elite                              1
# Evolution Games                    1
# UIG Entertainment                  1
# Name: count, Length: 578, dtype: int64

# %%
df['publisher']=df['publisher'].fillna('Electronic Arts')

# %%
df.isna().sum()
# Out:
# rank              0
# name              0
# platform          0
# year            271
# genre             0
# publisher         0
# na_sales          0
# eu_sales          0
# jp_sales          0
# other_sales       0
# global_sales      0
# dtype: int64

# %%
df
# Out:
# <bound method DataFrame.drop of         rank                                              name platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          year         genre   publisher  na_sales  eu_sales  jp_sales  \
# ...

# %%
df=df.dropna()
df.isna().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA Sales        0
# EU Sales        0
# JP Sales        0
# Other Sales     0
# Global Sales    0
# dtype: int64
