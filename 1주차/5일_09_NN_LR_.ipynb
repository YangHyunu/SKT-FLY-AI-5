# %% [markdown]
# <a href="https://colab.research.google.com/github/YangHyunu/SKT-FLY-AI-5/blob/main/1%EC%A3%BC%EC%B0%A8/5%EC%9D%BC_09_NN_LR_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## NN(Neural Network) 선형 회귀

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras

# %%
print(tf.__version__)
print(keras.__version__)
# Out:
# 2.15.0
# 2.15.0

# %%
# !pip install ipython-autotime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.7 MB/s eta 0:00:00
# ...

# %%
# %load_ext autotime
# Out:
# time: 441 µs (started: 2024-06-28 02:55:31 +00:00)

# %%
## 데이터 준비
# Out:
# time: 335 µs (started: 2024-06-28 02:56:09 +00:00)

# %%
X_train = np.array([1,2,3,4,5,6])
y_train = np.array([9,12,15,18,21,24])
# Out:
# time: 854 µs (started: 2024-06-28 02:57:23 +00:00)

# %%
plt.scatter(X_train,y_train)
# Out:
# time: 636 ms (started: 2024-06-28 02:57:42 +00:00)

# %% [markdown]
# ### LinearRegression

# %%
from sklearn.linear_model import LinearRegression
# Out:
# time: 1.21 s (started: 2024-06-28 02:59:13 +00:00)

# %%
X_train= X_train.reshape(-1,1)
y_train = y_train.reshape(-1,1)
# Out:
# time: 778 µs (started: 2024-06-28 03:03:38 +00:00)

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()
# time: 32.3 ms (started: 2024-06-28 03:03:40 +00:00)

# %%
lr.coef_,lr.intercept_ # y_hat = 3x+6
# Out:
# (array([[3.]]), array([6.]))
# time: 7.24 ms (started: 2024-06-28 03:04:10 +00:00)

# %%
y_pred_sk=lr.predict([[10]])
# Out:
# time: 3.79 ms (started: 2024-06-28 03:25:59 +00:00)

# %% [markdown]
# ## NN model

# %%
from keras import layers
model = keras.Sequential(
    layers.Dense(units=1,input_shape=(1,)))
# Out:
# time: 88.5 ms (started: 2024-06-28 04:29:30 +00:00)

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# time: 25.6 ms (started: 2024-06-28 04:12:28 +00:00)

# %%
model.compile(
    loss='mse',optimizer='adam',
    metrics=['mse']
)
# Out:
# time: 13.8 ms (started: 2024-06-28 04:30:57 +00:00)

# %%
model.fit(
    X_train,y_train,
    epochs=1000,
    batch_size=len(X_train)
)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 448ms/step - loss: 431.0741 - mse: 431.0741
# Epoch 2/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 430.8744 - mse: 430.8744
# Epoch 3/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 430.6747 - mse: 430.6747
# Epoch 4/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 430.4751 - mse: 430.4751
# Epoch 5/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 430.2755 - mse: 430.2755
# Epoch 6/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 430.0760 - mse: 430.0760
# Epoch 7/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 429.8765 - mse: 429.8765
# Epoch 8/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 429.6771 - mse: 429.6771
# Epoch 9/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 429.4778 - mse: 429.4778
# Epoch 10/1000
# ...

# %%
model.get_weights()
# Out:
# [array([[0.04952607]], dtype=float32), array([1.3949077], dtype=float32)]
# time: 6.71 ms (started: 2024-06-28 03:26:56 +00:00)

# %%
y_pred=model.predict([[10]])
y_pred
# Out:
# 1/1 [==============================] - 0s 69ms/step
# array([[1.8901684]], dtype=float32)
# time: 164 ms (started: 2024-06-28 03:28:47 +00:00)

# %%
plt.scatter(X_train,y_train)
plt.scatter([[10]],y_pred)
plt.scatter([[10]],y_pred_sk)
# Out:
# time: 250 ms (started: 2024-06-28 03:28:50 +00:00)
